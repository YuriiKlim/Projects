# %% [markdown]
# <a href="https://colab.research.google.com/github/YuriiKlim/Projects/blob/Military_detection/Military_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Oct 16 01:38:25 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.94                 Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:26:00.0  On |                  N/A |
# |  0%   38C    P8             N/A /  115W |    1427MiB /   8188MiB |     20%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
#!pip install ultralytics

# %%
import torch

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\klimk\AppData\Local\Programs\Python\Python312\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\klimk\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\cfg\__init__.py", line 773, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from 'C:\\Users\\klimk\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\ultralytics\\utils\\checks.py'>'. Valid modes are {'train', 'predict', 'val', 'benchmark', 'track', 'export'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'obb', 'detect', 'pose', 'segment', 'classify'}
# ...

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
os.environ['TORCH_USE_CUDA_DSA'] = '1'


device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)
generator = torch.Generator(device='cuda')

# %%
dataset_dir = "C:/Users/klimk/Desktop/Military_1.v2i.yolov11"
dataset_yaml = os.path.join(dataset_dir, "data.yaml")

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset_dir}/data.yaml device=cuda batch=64 epochs=100 imgsz=640 project={dataset_dir} name=Military_yolov11
# Out:
# New https://pypi.org/project/ultralytics/8.3.13 available рџ�ѓ Update with 'pip install -U ultralytics'
# Ultralytics 8.3.8 рџљЂ Python-3.12.0 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060, 8187MiB)
# ...

# %% [markdown]
# ![labels.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![results.png](data:image/png;base64,...)

# %% [markdown]
# ![confusion_matrix.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
